# %%
# Student Performance Analyzer

def calculate_grade(marks):
    if marks >= 90:
        return "A+"
    elif marks >= 80:
        return "A"
    elif marks >= 70:
        return "B"
    elif marks >= 60:
        return "C"
    elif marks >= 50:
        return "D"
    else:
        return "F"


def analyze_students():
    students = []

    # Input data for 5 students
    for i in range(5):
        print(f"\nEnter details for Student {i+1}")
        name = input("Name: ")
        marks = float(input("Marks: "))

        student_data = {
            "name": name,
            "marks": marks,
            "grade": calculate_grade(marks)
        }

        students.append(student_data)

    # Calculate topper
    topper = max(students, key=lambda x: x["marks"])

    # Calculate class average
    total_marks = sum(student["marks"] for student in students)
    class_average = total_marks / len(students)

    # Display Results
    print("\n----- Student Report -----")
    for student in students:
        print(f"{student['name']} - Marks: {student['marks']} - Grade: {student['grade']}")

    print("\nTopper:", topper["name"], "with", topper["marks"], "marks")
    print("Class Average:", round(class_average, 2))


# Run the program
analyze_students()
# Out:
# Enter details for Student 1
# Name: Alice
# Marks: 94
#
# Enter details for Student 2
# Name: Bob
# Marks: 85
#
# Enter details for Student 3
# Name: John
# Marks: 74
#
# Enter details for Student 4
# Name: Rayn
# Marks: 56
#
# Enter details for Student 5
# Name: Reyansh
# Marks: 40
#
# ----- Student Report -----
# Alice - Marks: 94.0 - Grade: A+
# Bob - Marks: 85.0 - Grade: A
# John - Marks: 74.0 - Grade: B
# Rayn - Marks: 56.0 - Grade: D
# Reyansh - Marks: 40.0 - Grade: F
#
# Topper: Alice with 94.0 marks
# Class Average: 69.8
