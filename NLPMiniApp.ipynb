# %%
# NLP Keyword Extractor - 3/4/2026

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
nltk.download('punkt_tab')

# Download required resources (run once)
nltk.download('punkt')
nltk.download('stopwords')

# Input text
text = """Artificial Intelligence is transforming the world.
It helps in automation, data analysis, and decision making."""

# Clean text
text = re.sub(r'[^a-zA-Z ]', '', text)

# Tokenize
words = word_tokenize(text.lower())

# Remove stopwords
filtered_words = [w for w in words if w not in stopwords.words('english')]

# Frequency count
freq = {}
for word in filtered_words:
    freq[word] = freq.get(word, 0) + 1

# Sort keywords
keywords = sorted(freq, key=freq.get, reverse=True)

print("Extracted Keywords:")
print(keywords)
# Out:
# Extracted Keywords:
# ['artificial', 'intelligence', 'transforming', 'world', 'helps', 'automation', 'data', 'analysis', 'decision', 'making']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
