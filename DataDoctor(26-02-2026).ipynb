# %%
# Data Doctor Assignment - Advanced Dataset Cleaning

import pandas as pd
import numpy as np

# -----------------------------
# Step 1: Create Sample Dataset
# -----------------------------
data = {
    "Name": ["Amit", "Sara", "John", "Sara", "Anu", "Ravi", "amit"],
    "Age": [20, 21, np.nan, 21, 22, 200, 20],
    "Department": ["CS", "IT", "CS", "IT", None, "cs", "CS"],
    "Marks": [85, 90, 78, 90, np.nan, 150, 85]
}

df = pd.DataFrame(data)

print("Original Dataset:\n")
print(df)

# -----------------------------
# Step 2: Check Missing Values
# -----------------------------
print("\nMissing Values:")
print(df.isnull().sum())

# -----------------------------
# Step 3: Handle Missing Values
# -----------------------------
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Marks"].fillna(df["Marks"].mean(), inplace=True)
df["Department"].fillna("Unknown", inplace=True)

# -----------------------------
# Step 4: Remove Duplicate Rows
# -----------------------------
df = df.drop_duplicates()

# -----------------------------
# Step 5: Standardize Text Data
# -----------------------------
df["Name"] = df["Name"].str.lower().str.strip()
df["Department"] = df["Department"].str.lower().str.strip()

# -----------------------------
# Step 6: Fix Outliers
# -----------------------------
# Remove unrealistic ages
df.loc[df["Age"] > 100, "Age"] = df["Age"].median()

# Remove unrealistic marks
df.loc[df["Marks"] > 100, "Marks"] = df["Marks"].mean()

# -----------------------------
# Step 7: Data Summary Report
# -----------------------------
print("\nCleaned Dataset:\n")
print(df)

print("\nDataset Summary:")
print(df.describe())

print("\nUnique Departments:", df["Department"].unique())

# -----------------------------
# Step 8: Save Clean Dataset
# -----------------------------
df.to_csv("cleaned_students.csv", index=False)

print("\nData cleaning completed. File saved as 'cleaned_students.csv'")
# Out:
# Original Dataset:
#
#    Name    Age Department  Marks
# 0  Amit   20.0         CS   85.0
# 1  Sara   21.0         IT   90.0
# 2  John    NaN         CS   78.0
# 3  Sara   21.0         IT   90.0
# 4   Anu   22.0        NaN    NaN
# 5  Ravi  200.0         cs  150.0
# 6  amit   20.0         CS   85.0
#
# Missing Values:
# Name          0
# Age           1
# Department    1
# Marks         1
# dtype: int64
#
# Cleaned Dataset:
#
#    Name   Age Department  Marks
# 0  amit  20.0         cs   85.0
# 1  sara  21.0         it   90.0
# 2  john   NaN         cs   78.0
# 4   anu  22.0        NaN    NaN
# 5  ravi  21.0         cs   97.6
# 6  amit  20.0         cs   85.0
#
# Dataset Summary:
#             Age      Marks
# count   5.00000   5.000000
# mean   20.80000  87.120000
# std     0.83666   7.250655
# min    20.00000  78.000000
# 25%    20.00000  85.000000
# 50%    21.00000  85.000000
# 75%    21.00000  90.000000
# max    22.00000  97.600000
#
# Unique Departments: <StringArray>
# ['cs', 'it', nan]
# Length: 3, dtype: str
#
# Data cleaning completed. File saved as 'cleaned_students.csv'
# C:\Users\HP\AppData\Local\Temp\ipykernel_5548\1803354279.py:30: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_5548\1803354279.py:31: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_5548\1803354279.py:32: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Department"].fillna("Unknown", inplace=True)
